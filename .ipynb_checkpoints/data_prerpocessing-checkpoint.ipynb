# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession, HiveContext 

import math, sys, glob, random, os, traceback, itertools
import sympy
import numpy as np
import pandas as pd

from nltk import ngrams, word_tokenize
import json

import time
import re

from operator import add

import matplotlib.pyplot as plt
plt.style.use('ggplot')

conf = SparkConf().setMaster("local").setAppName("Final")
sc = SparkContext(conf=conf)
spark = SparkSession(sc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b71bc7aae6a7> in <module>
#      19
#      20 conf = SparkConf().setMaster("local").setAppName("Final")
# ---> 21 sc = SparkContext(conf=conf)
#      22 spark = SparkSession(sc)
#
# ~/anaconda3/lib/python3.7/site-packages/pyspark/context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     131                     " note this option will be removed in Spark 3.0")
#     132
# --> 133         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     134         try:
#     135             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# ~/anaconda3/lib/python3.7/site-packages/pyspark/context.py in _ensure_initialized(cls, instance, gateway, conf)
#     330                         " created by %s at %s:%s "
#     331                         % (currentAppName, currentMaster,
# --> 332                             callsite.function, callsite.file, callsite.linenum))
#     333                 else:
#     334                     SparkContext._active_spark_context = instance
#
# ValueError: Cannot run multiple SparkContexts at once; existing SparkContext(app=Final, master=local) created by __init__ at <ipython-input-1-b71bc7aae6a7>:21

# %%
def except_hanlder(file):
    multi_file=False
    with open(file, 'r') as f:
        file  =f.read()
    #     print(file)
        file = [ file for file in file.split('}{')]
    #     file[-1] = file[-1][:-1]
        for i, data in enumerate(file):
    #         print(data)
            if i != 0:
                data = '{' + data
            if i != len(file)-1:
                data = data + '}'
            file[i] = data
        abc = file
    #     print(json.loads(json.dumps(file).strip()))
    #         print(data)
    print('[INFO]: Does the file duplicate',end='? ')
    if abc[0] == abc[1]:
        print('Yes')
        abc = set(abc)
    else:
        multi_file = True
        print('No')
    return abc, multi_file
#     t = eval(abc[1])
    
#     return 
    # print(abc)

# %%
root_dir = '../data/ID_Multi'
date_list = os.listdir(root_dir)

json_raw_list = []
rewrite=False
c = 0
for date in date_list:
    sub_dir = os.path.join(root_dir, date)
    json_file_list = os.listdir(sub_dir)
    for json_file in json_file_list:
        open_file = os.path.join(sub_dir, json_file)
        with open(open_file, 'r') as f:
            try:
                data = json.load(f)
            except ValueError as e:  # includes simplejson.decoder.JSONDecodeError
                rewrite = True
                c+=1
                error_class = e.__class__.__name__ #取得錯誤類型
                detail = e.args[0]                 #取得詳細內容
                t = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()) 
                errMsg = f"{error_class:<10}: {detail:<70} {t}"
                handlingMsg = f"[INFO]: Get exception"
                print(errMsg)
                print(handlingMsg)
                data, multi_file = except_hanlder(open_file)
        if(rewrite):
            print('[INFO]: Now re-writting the json file....')
            fc = 1
            rewrite_file = str(fc) + '_' + json_file
            rewrite_file = os.path.join(sub_dir, rewrite_file)
            for d in data:
                with open('./'+str(fc)+'.json','w') as rf:
                    rf.write(d)
                json_raw_list.append(eval(d))
                
            print('[INFO]: Removing the old version....')
            os.remove(open_file)
            if os.path.exists(open_file):
                print(f'[INFO]: {open_file} has been removed successfully!\n')
            rewrite = False
        else:
            json_raw_list.append(data)
print(f'Total {c} files have been rewrite!')
# Out:
# Total 0 files have been rewrite!

# %% [markdown]
# ## <center><span style="color:blue;font-size:30px">below is testing Don't mind this</span></center>

# %%
count = 0
for i in json_raw_list:
    if 'dict' in str(type(i)):
        count +=1
if count == len(json_raw_list):
    print('yee')
# Out:
# yee

# %%
len(json_raw_list)
# Out:
# 6303

# %%
json_raw_list[0].keys()
# Out:
# dict_keys(['article_id', 'article_title', 'author', 'board', 'content', 'date', 'ip', 'message_conut', 'messages'])

# %%
c = 0
for i in json_raw_list:
#     r = '[1-9]+個ID'
#     t = re.findall(r, i['content'])
#     if '帳號砍除' in i['article_title']:
#         c+=1
#     elif '清除異常帳號' in i['article_title']:
#         c+=1
#     if '公告' in i['article_title'] and '砍除'not in i['article_title'] and '清除' not in i['article_title']\
#                 and '不受歡迎' not in i['article_title'] and '停權' not in i['article_title']:
    if 'Re:' not in i['article_title'] and '[公告]' in i['article_title'] and 'Fw' in i['article_title']:
#     if 'Re:' not in i['article_title'] and '[公告]' in i['article_title'] and '清除' in i['article_title'] and '機器人'not in i['article_title']:
#     if 'Re:' not in i['article_title'] and '[公告]' in i['article_title'] and '砍除' in i['article_title']:
#     if 'Re:' not in i['article_title'] and '[公告]' in i['article_title'] and'Fw:' not in i['article_title']:
#         if '砍除' in i['article_title']:
#         start = '註：'
#         end = '(ID_Multi)'
#         tmp = i['content'].split(' ')
#         try:
#             ii = tmp.index('(ID_Multi)')
#         except ValueError:
#             ii = -1

#             if '轉錄' in i['content']:
# #                 c+=1
#                 st = i['content'].find('轉錄')
#                 tmp1 = i['content'][st:].split(' ')
#                 ii = [ idx for idx, t in enumerate(tmp1) if '轉錄至看板' in t]
#                 tmp = [ tmp1[iii+1] for iii in ii]
#                 print(tmp)
#             else:
#                 c+=1
#     m = i['messages']
#     if len(m) !=0:
#         if '' in m[0].values():
#             print(m[0].values())

                
        
#             if '轉錄' in m:
#                 print(m)
#             if '轉錄至看板' in 

#             print(i['content'])
#         en = i['content'].find(end)
#         tmp = i['content'][:en]
#         tmp = re.sub(r'[\W_]+', ' ', i['content'])
#         tmp = re.findall(r'[A-Za-z0-9]+', tmp)
#         st = i[''].find(start)
#         tmp = i['content'][st:-1]
#         print(i['content'], i['date'])
#         print(i['article_title'])
#         print(tmp)
        print(i['message_conut'])
#         print(ii)
#     print('\n\n\n\n')
print(c)
# 1TcpnpBS, 1TcpkWEz

# 轉錄至某隱形看板, 轉錄至看板
#
# Out:
# {'all': 0, 'boo': 0, 'count': 0, 'neutral': 0, 'push': 0}
# {'all': 0, 'boo': 0, 'count': 0, 'neutral': 0, 'push': 0}
# {'all': 0, 'boo': 0, 'count': 0, 'neutral': 0, 'push': 0}
# {'all': 108, 'boo': 2, 'count': 55, 'neutral': 49, 'push': 57}
# {'all': 0, 'boo': 0, 'count': 0, 'neutral': 0, 'push': 0}
# 0

# %%
title = ['HatePolitics', 'Gossiping', 'politics', 'WomenTalk']

# %% [markdown]
# ## <center><span style="color:blue;font-size:30px">above is testing Don't mind this</span></center>

# %%
for i in json_raw_list:
    if 'Re:' not in i['article_title'] and '[公告]' in i['article_title'] and 'Fw' not in i['article_title']:
        print(i['author'])

#         if '出售' in i['article_title']:
#             tmp = i['content']
#             start = '正出售中或曾經出售之帳號：'
#             end = '另'
#             st = tmp.find(start)
#             en = tmp.find(end)
#             tmp = tmp[st:en]
#             tmp = re.sub(r'[\W_]+', ' ', tmp)
#             tmp = re.findall('[A-Za-z0-9]+', tmp)
#             print(tmp)
#             print(i['content'])
#             if '轉錄至' in i['content']:
#                 print(i['article_title'])
#             print(i['article_title'])
# Out:
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# iamori (我會想妳的)
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# iamori (我會想妳的)
# Makotoyen (暫離。)
# penlyly (請勿拍打與餵食)
# disFabulous (              )
# disFabulous (              )
# jzs (推ｄ神一針見血)
# jzs (推ｄ神一針見血)
# jzs (推ｄ神一針見血)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# jzs (推ｄ神一針見血)
# John7 (正直和善良会回来)
# penlyly (請勿拍打與餵食)
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# jzs (值班 開團 敗家)
# disFabulous (              )
# disFabulous (              )
# c0c0nIng (正妹???)
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (暫離。)
# Makotoyen (暫離。)
# penlyly (請勿拍打與餵食)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# orion (火星上的人類學家)
# disFabulous (              )
# Makotoyen (暫離。)
# Makotoyen (Mr.麻摳抖)
# Makotoyen (暫離。)
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# penlyly (請勿拍打與餵食)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# Makotoyen (Mr.麻摳抖)
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# Junchoon (裘髯客)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# penlyly (請勿拍打與餵食)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# iamori (我會想妳的)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (暫離。)
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# iamori (我會想妳的)
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# iamori ()
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# Makotoyen (暫離。)
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# iamori (我會想妳的)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Junchoon (裘髯客)
# Junchoon (裘髯客)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (Mr.麻摳抖)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# Makotoyen (暫離。)
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# disFabulous (              )
# penlyly (請勿拍打與餵食)
# disFabulous (              )

# %% [markdown]
# |  [公告] |   清除  |  砍除  |  停權  |  砍除＆停權  | 不受歡迎 | 機器人帳號 |  其他 | 總共 |
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# |   數量  |   24   |  219   |   17  |     36     |    10   |     7    |   64  | 377 |
#
# ---
# >[申請]<br>
# >>多重帳號查詢<br>
#
# >[公告]
# >>**砍除**
# >>>砍除帳號<br>
# >>>帳號砍除<br>
#
# >>**清除 #24**
# >>>VPN #2<br>
# >>>出售 #1.<br>
# >>>共同帳號<br>
#
# >[檢舉]

# %%
wrong_people = [['taboo00',['fake','xx', 'xx', 'xx']]]
# wrong_people = (['WWWWW123',['fake','xx']],  ['lllxxxlll',['fake','xx']], ['taboo00',['fake','xx']])
rdd_wrongPeople = sc.parallelize(wrong_people)
rdd_wrongPeople.collect()
# Out:
# [['taboo00', ['fake', 'xx', 'xx', 'xx']]]

# %%
boss_list = []
for i in json_raw_list:
    if 'Re:' not in i['article_title'] and '[公告]' in i['article_title'] and 'Fw' not in i['article_title']:
        boss_list.append(i['author'].split()[0])
boss_list = list(set(boss_list))
print(boss_list)
# Out:
# ['jzs', 'c0c0nIng', 'penlyly', 'orion', 'Junchoon', 'John7', 'disFabulous', 'Makotoyen', 'iamori']

# %%
boss = [ [b, ['fake', 'xx', 'xx', 'xx']] for b in boss_list]
rdd_boss = sc.parallelize(boss)
rdd_boss.collect()
# Out:
# [['jzs', ['fake', 'xx', 'xx', 'xx']],
#  ['c0c0nIng', ['fake', 'xx', 'xx', 'xx']],
#  ['penlyly', ['fake', 'xx', 'xx', 'xx']],
#  ['orion', ['fake', 'xx', 'xx', 'xx']],
#  ['Junchoon', ['fake', 'xx', 'xx', 'xx']],
#  ['John7', ['fake', 'xx', 'xx', 'xx']],
#  ['disFabulous', ['fake', 'xx', 'xx', 'xx']],
#  ['Makotoyen', ['fake', 'xx', 'xx', 'xx']],
#  ['iamori', ['fake', 'xx', 'xx', 'xx']]]

# %%
json_raw_content = [ [j['article_title'], j['content'] ,j['date'], j['article_id'], j['message_conut']] for j in json_raw_list]
json_rdd = sc.parallelize(json_raw_content)

# %%
# ===========================================================================================

# 砍除
def map_kill(x):
    if '[公告]' in x[0] and '砍除' in x[0] and 'Re:' not in x[0] and 'Fw:' not in x[0] and '停權' not in x[0]:#帳號砍除
        return True
    else:
        return False

def kill_proc(x):
    tmp = re.sub(r'[\W_]+', ' ', x[0])
    tmp = re.findall(r'[A-Za-z0-9]+', tmp)
    tmp = [ [t, ['砍除', x[2], x[3], x[4]]] for t in tmp]
    return tmp
# ===========================================================================================


# 停權
def map_suspend(x):
    if '[公告]' in x[0] and 'Re' not in x[0] and 'Fw:' not in x[0] and '停權' in x[0] and '砍除' not in x[0] and '砍帳' not in x[0]:
        return True
    else:
        return False

    
def suspend_proc(x):
    tmp = re.sub(r'[\W_]+', ' ', x[0])
    tmp = re.findall(r'[A-Za-z0-9]+', tmp)
    tmp = [ [t, ['停權', x[2], x[3], x[4]]] for t in tmp]
    return tmp
# ===========================================================================================
# 砍除&停權
def map_killSuspend(x):
    if '[公告]' in x[0] and 'Re' not in x[0] and 'Fw:' not in x[0] and '停權' in x[0] and '砍除' in x[0] and '砍帳' not in x[0]:
        return True
    else:
        return False

    
def killSuspend_proc(x):
    tmp = x[0].split('/')
    if '砍除' in tmp[0]:
        tmp1 = re.sub(r'[\W_]+', ' ', tmp[0])
        tmp1 = re.findall(r'[A-Za-z0-9]+', tmp1)
        tmp2 = re.sub(r'[\W_]+', ' ', tmp[1])
        tmp2 = re.findall(r'[A-Za-z0-9]+', tmp2)
        tmp = [ [[t, ['砍除', x[2], x[3], x[4]]] for t in tmp1], [[t, ['停權', x[2], x[3], x[4]]] for t in tmp2]  ]
    else:
        tmp1 = re.sub(r'[\W_]+', ' ', tmp[0])
        tmp1 = re.findall(r'[A-Za-z0-9]+', tmp1)
        tmp2 = re.sub(r'[\W_]+', ' ', tmp[1])
        tmp2 = re.findall(r'[A-Za-z0-9]+', tmp2)
        tmp = [ [[t, ['砍除', x[2], x[3], x[4]]] for t in tmp2], [ [t, ['停權', x[2], x[3], x[4]]] for t in tmp1] ]

    return tmp


# ===========================================================================================

# 不受歡迎
def map_unWellcome(x):
    if '[公告]' in x[0] and 'Re' not in x[0] and 'Fw:' not in x[0] and '不受歡迎' in x[0] and '規範' not in x[0]:
        return True
    else:
        return False

    
def unWellcome_proc(x):
    tmp = re.sub(r'[\W_]+', ' ', x[0])
    tmp = re.findall(r'[A-Za-z0-9]+', tmp)
    tmp = [ [t, ['不受歡迎', x[2], x[3], x[4]]] for t in tmp]
    return tmp
# ===========================================================================================

def map_robot(x):
    if '[公告]' in x[0] and 'Re' not in x[0] and 'Fw:' not in x[0] and'機器人' in x[0]:
        return True
    else:
        return False
    
    
def robot_proc(x):
    start = '砍除帳號如下：'
    end = '帳號站長'
    st = x[1].find(start)
    en = x[1].find(end)
    tmp = x[1][st:en]
    tmp = re.sub(r'[\W_]+', ' ', tmp)
    tmp = re.findall(r'[A-Za-z0-9]+', tmp)
    tmp = [t for t in tmp if len(t) > 2]
    tmp = [ [t, ['機器人', x[2], x[3], x[4]]] for t in tmp]
    return tmp
# ***************===========================================================================================

# 清除出售
def filter_cleanOverFive(x):
    if '清除正或曾出售之帳號' in x[0] and '公告' in x[0] and 'Re:' not in x[0] and 'Fw:' not in x[0]:
        return True
    else:
        return False

def cleanSold_proc(x):
    start = ['同一人或同一集團持有或使用：', '兩案涉案帳號如下：']
    end = '依多重帳號管理辦法'
    st = [x[1].find(s) for s in start]
    st = max(list(filter(lambda x: x>0, st)))
    en = x[1].find(end)
    tmp = x[1][st:en]
    tmp = re.sub(r'[\W_]+', ' ', tmp)
    tmp = re.findall(r'[A-Za-z0-9]+', tmp)
    tmp = [ [t, ['清除共同帳號', x[2], x[3], x[4]]] for t in tmp]
    return tmp




# 超過五名帳號
def filter_cleanOverFive(x):
    if '超過五名帳號' in x[0] and '公告' in x[0] and 'Re:' not in x[0] and 'Fw:' not in x[0]:
        return True
    else:
        return False

def cleanOverFive_proc(x):
    start = ['同一人或同一集團持有或使用：', '兩案涉案帳號如下：']
    end = '依多重帳號管理辦法'
    st = [x[1].find(s) for s in start]
    st = max(list(filter(lambda x: x>0, st)))
    en = x[1].find(end)
    tmp = x[1][st:en]
    tmp = re.sub(r'[\W_]+', ' ', tmp)
    tmp = re.findall(r'[A-Za-z0-9]+', tmp)
    tmp = [ [t, ['清除共同帳號', x[2], x[3], x[4]]] for t in tmp]
    return tmp


# 清除帳號 24
def map_clean(x):
    if '[公告]' in x[0] and '清除' in x[0] and 'Re:' not in x[0] and 'Fw:' not in x[0] and '機器人' not in x[0] and '出售' not in x[0]:#清除大量異常帳號
        return True
    else:
        return False


# 清除共同帳號 13
def cleanSame_proc(x):
    start = '下列帳號予以清除：'
    end = ['註： ', '上列部分帳號曾使用信箱認證。', '帳號站長']
    st = x[1].find(start)
    en = [ x[1].find(e) for e in end ]
    en = min(list(filter(lambda x: x >= 0, en)))
    tmp = x[1][st:en]
    # 有備註的
    if '註：' in tmp:
        tmp = tmp[:tmp.find('註：')]
        tmp = re.sub(r'[\W_]+', ' ', tmp)
        tmp = re.findall(r'[A-Za-z0-9]+', tmp)
        tmp = [ [t, ['清除共同帳號', x[2], x[3], x[4]]] for t in tmp]
        
        return tmp
    # 沒有備註的
    else:
        tmp = re.sub(r'[\W_]+', ' ', tmp)
        tmp = re.findall(r'[A-Za-z0-9]+', tmp)
        tmp = [ [t, ['清除共同帳號', x[2], x[3], x[4]]] for t in tmp]

        return tmp

# 清除跳板帳號 7
def cleanJump_proc(x):
    start = '砍除帳號：'
    end = ['註：曾因帳號遭盜用報案者', '上列部分帳號曾使用信箱認證。']
    st = x[1].find(start)
    en = [ x[1].find(e) for e in end ]
    en = min(list(filter(lambda x: x > 0, en)))
    tmp = x[1][st:en]
#     date = handle_date(x[2])
    if '刪除ID:' in tmp:
        tmp = tmp.split()
        tmp = [tmp[i+1] for i,v in enumerate(tmp) if v == '刪除ID:']
        tmp = [ [t, ['清除跳板帳號', x[2], x[3], x[4]]] for t in tmp]
        return tmp
    else:
        tmp = re.sub(r'[\W_]+', ' ', tmp)
        tmp = re.findall(r'[A-Za-z0-9]+', tmp)
        tmp = [ [t, ['清除跳板帳號', x[2], x[3], x[4]]] for t in tmp]
        return tmp
    
# 清除VPN帳號 2
def cleanVPN_proc(x):
    start = [ '清除帳號如下：', '下列帳號予以刪除：']
    end = '帳號站長'
    st = [ x[1].find(s) for s in start ]
    st = min(list(filter(lambda x: x > 0, st)))
    en = x[1].find(end)
    tmp = x[1][st:en]
    tmp = re.sub(r'[\W_]+', ' ', tmp)
    tmp = re.findall(r'[A-Za-z0-9]+', tmp)
    tmp = [ [t, ['清除VPN帳號', x[2], x[3], x[4]]] for t in tmp]
    
    return tmp

# 不實資料 1
def cleanFakeInfo_proc(x):
    start = '全數砍除.'
    end = '日後若再發現同一人使用或持有之帳號'
    st = x[1].find(start)
    en = x[1].find(end)
    tmp = x[1][st:en]
    tmp = re.sub(r'[\W_]+', ' ', tmp)
    tmp = re.findall(r'[A-Za-z0-9]+', tmp)
    tmp = [ [t, ['清除不實資料帳號', x[2], x[3], x[4]]] for t in tmp]
    return tmp

def f(x):
    prior_level = {'清除共同帳號':0, '清除跳板帳號':0, '清除VPN帳號':0, '清除不實資料帳號':0,
                   '機器人':     1,
                   '砍除':       2,
                   '停權':       3,
                   '不受歡迎':   4}
    mini = 100
    mini_idx = -1
    if len(x[1]) == 4 and 'fake' != x[1][0]:
        return x
    for idx in range(0, len(x[1]), 4):
        if 'fake' == x[1][idx]:
            return [x[0], ['del', 'del', 'del', 'del']]
        key = x[1][idx]
        if prior_level[key] < mini:
            mini = prior_level[key]
            mini_idx = idx
    return [ x[0], [x[1][mini_idx], x[1][mini_idx+1], x[1][mini_idx+2], x[1][mini_idx+3]] ]



#     for idx, duplicate in enumerate(x[1])
def restore(x):
    type_date = x[0].split('/')
    return [type_date[0], x[1], type_date[1]]
    
def handle_date(x):
    mouth = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'Jun':'06', 'Jul':'07', 'Aug':'08',
             'Sep':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}
    day = {'Mon':'1', 'Tue':'2', 'Wed':'3', 'Thu':'4', 'Fri':'5', 'Sat':'6', 'Sun':'7'}    
    tmp = re.sub(r'[\W_]+', ' ', x).split(' ')
    return tmp[6]+'-'+mouth[tmp[1]]+'-'+tmp[2]+'-'+day[tmp[0]]

# 清除超過五名帳號
rdd_cleanOverFive = json_rdd.filter(lambda x: filter_cleanOverFive(x))\
                            .flatMap(lambda x: cleanOverFive_proc(x))

# rdd_total.collect()



# 清除共同
rdd_cleanSame = json_rdd.filter(lambda x: map_clean(x) )\
                        .filter(lambda x: '不實資料註冊' not in x[1])\
                        .filter(lambda x: 'VPN' not in x[1])\
                        .filter(lambda x: '跳板' not in x[1])\
                        .filter(lambda x: '下列帳號予以清除：' in x[1])\
                        .flatMap(lambda x: cleanSame_proc(x))\
#                         .map(lambda x: [x[0], x[1]])\#==================
#                         .reduceByKey(add)\
#                         .map(lambda x: len(set(x[1])))#==================
#                         .map(lambda x: [ x[0], list(set(x[1]))])\


# # 清除跳板
rdd_cleanJump = json_rdd.filter(lambda x: map_clean(x) )\
                        .filter(lambda x: '不實資料註冊' not in x[1])\
                        .filter(lambda x: 'VPN' not in x[1])\
                        .filter(lambda x: '跳板' in x[1])\
                        .flatMap(lambda x: cleanJump_proc(x))\
#                         .map(lambda x: [x[0], x[1]])\#==================
#                         .reduceByKey(add)\
#                         .map(lambda x: len(set(x[1])))#==================
#                         .reduceByKey(add)\
#                         .map(lambda x: [ x[0], list(set(x[1]))])\

# # 清除vpn
rdd_cleanVPN = json_rdd.filter(lambda x: map_clean(x) )\
                        .filter(lambda x: '不實資料註冊' not in x[1])\
                        .filter(lambda x: 'VPN' in x[1])\
                        .flatMap(lambda x: cleanVPN_proc(x))\
#                         .map(lambda x: [x[0], x[1]])\#==================
#                         .reduceByKey(add)\
#                         .map(lambda x: len(set(x[1])))#==================
#                         .reduceByKey(add)\
#                         .map(lambda x: [ x[0], list(set(x[1]))])\

# # 清除不實資料
rdd_cleanFakeInfo = json_rdd.filter(lambda x: map_clean(x) )\
                            .filter(lambda x: '不實資料註冊' in x[1])\
                            .flatMap(lambda x: cleanFakeInfo_proc(x))\
#                 .map(lambda x: [x[0], x[1]])\#==================
#                 .reduceByKey(add)\
#                 .map(lambda x: len(set(x[1])))#==================
#                 .reduceByKey(add)\
#                 .map(lambda x: [ x[0], list(set(x[1]))])\


# # 砍除 
rdd_kill = json_rdd.filter(lambda x: map_kill(x) )\
                .flatMap(lambda x: kill_proc(x))\
#                 .map(lambda x: [x[0], x[1]])\#==================
#                 .reduceByKey(add)\
#                 .map(lambda x: len(set(x[1])))#==================
#                 .reduceByKey(add)

# # # 停權 
rdd_suspend = json_rdd.filter(lambda x: map_suspend(x) )\
                .flatMap(lambda x: suspend_proc(x))\
#                 .map(lambda x: [x[0], x[1]])\#==================
#                 .reduceByKey(add)\
#                 .map(lambda x: len(set(x[1])))#==================
# #                 .reduceByKey(add)


# # 砍除&停權 
rdd_killSuspend = json_rdd.filter(lambda x: map_killSuspend(x) )\
                .flatMap(lambda x: killSuspend_proc(x))\
                .flatMap(lambda x: x)\
#                 .map(lambda x: [x[0], x[1]])\#==================
#                 .reduceByKey(add)\
#                 .map(lambda x: len(set(x[1])))#==================
# #                 .reduceByKey(add)

# 不受歡迎
rdd_unWellcome = json_rdd.filter(lambda x: map_unWellcome(x) )\
                .flatMap(lambda x: unWellcome_proc(x))\
#                 .flatMap(lambda x: map4_proc(x))\
#                 .map(lambda x: [x[0], x[1]])\#==================
#                 .reduceByKey(add)\
#                 .map(lambda x: len(set(x[1])))#==================
#                 .reduceByKey(add)

# 機器人
rdd_robot = json_rdd.filter(lambda x: map_robot(x) )\
                .flatMap(lambda x: robot_proc(x))\
#                 .map(lambda x: [x[0], x[1]])\#==================
#                 .reduceByKey(add)\
#                 .map(lambda x: len(set(x[1])))#==================
#                 .reduceByKey(add)
a = ['rockx80', 'jeff2004618', 'alexyu33', 'ssjik', 'ccu15']

                                            
rdd_totalByType = sc.union([rdd_cleanOverFive, rdd_cleanSame, rdd_cleanJump, rdd_cleanVPN, rdd_cleanFakeInfo,
                            rdd_kill, rdd_suspend, rdd_killSuspend,
                            rdd_unWellcome, rdd_robot,
                            rdd_wrongPeople, rdd_boss])\
                    .reduceByKey(add)\
                    .map(lambda x: f(x))\
                    .filter(lambda x: x[1][0] != 'del')\

rdd_total = rdd_totalByType.map(lambda x: [ x[1][0], [x[0], x[1][1], x[1][2], x[1][3]] ])\
                            .groupByKey()\
                            .map(lambda x: [x[0], list(x[1])])\
                            .flatMap(lambda x: [ [x[0], xx] for xx in x[1] ])\
                            .map(lambda x: [x[0], x[1][0], handle_date(x[1][1]), x[1][2], x[1][3]])\
#                             .map(lambda x: ( x[0], x[1], handle_date(x[2]), x[3], x[4] ))\
# 
#                             .map(lambda x: [x[0]+'/'+x[1][1], x[1][0]])\
#                             .groupByKey()\
#                             .map(lambda x: [x[0], list(x[1])])\
#                             .map(lambda x: restore(x))\
#                             .sortByKey()
df = rdd_total.toDF(['Type', 'ID', 'Date', 'ID_Group', 'Popularity']).toPandas()
# 清除跳板帳號, 停權, 清除不實資料帳號
# rdd_total.collect()
# wrong_people.collect()
# 不受歡迎 冤案 WWWWW123 lllxxxlll  taboo00
# rockx80, jeff2004618, alexyu33, ssjik, ccu15 同一人或同一集團持有或使用：, 依多重帳號管理辦法, 兩案涉案帳號如下：

# %%
set(df['Type'])
# Out:
# {'不受歡迎', '停權', '機器人', '清除VPN帳號', '清除不實資料帳號', '清除共同帳號', '清除跳板帳號', '砍除'}

# %%
set(df.columns.values)
# Out:
# {'Date', 'ID', 'ID_Group', 'Type'}

# %%
df.loc[df['Type'] == '清除共同帳號']
# Out:
#         Type          ID          Date            ID_Group  \
# 5530  清除共同帳號        ssrr  2019-07-17-3  M.1563302412.A.B45
# 5531  清除共同帳號       bregg  2019-07-17-3  M.1563302412.A.B45
# 5532  清除共同帳號      hoiiwu  2019-07-18-4  M.1563385142.A.D4E
# 5533  清除共同帳號     cmjienn  2019-07-18-4  M.1563385142.A.D4E
# 5534  清除共同帳號   merrygrgm  2019-11-23-6  M.1574483489.A.AE5
# 5535  清除共同帳號       nets7  2019-11-23-6  M.1574483489.A.AE5
# 5536  清除共同帳號        cncn  2019-11-23-6  M.1574483489.A.AE5
# 5537  清除共同帳號        SR72  2019-11-23-6  M.1574483489.A.AE5
# 5538  清除共同帳號      haahoo  2019-11-23-6  M.1574483489.A.AE5
# 5539  清除共同帳號       Bixby   2019-06-6-4  M.1559793935.A.90C
# 5540  清除共同帳號        Enfo   2019-06-6-4  M.1559793935.A.90C
# 5541  清除共同帳號       EYELA   2019-06-6-4  M.1559793935.A.90C
# 5542  清除共同帳號       Fatoe   2019-06-6-4  M.1559793935.A.90C
# 5543  清除共同帳號      GAS991   2019-06-6-4  M.1559793935.A.90C
# 5544  清除共同帳號        Hoto   2019-06-6-4  M.1559793935.A.90C
# 5545  清除共同帳號        ID42   2019-06-6-4  M.1559793935.A.90C
# 5546  清除共同帳號       InnoX   2019-06-6-4  M.1559793935.A.90C
# 5547  清除共同帳號      ISPnet   2019-06-6-4  M.1559793935.A.90C
# 5548  清除共同帳號       KHLRT   2019-06-6-4  M.1559793935.A.90C
# 5549  清除共同帳號       LILIO   2019-06-6-4  M.1559793935.A.90C
# 5550  清除共同帳號    Line0800   2019-06-6-4  M.1559793935.A.90C
# 5551  清除共同帳號      LoLoGo   2019-06-6-4  M.1559793935.A.90C
# 5552  清除共同帳號        LTPS   2019-06-6-4  M.1559793935.A.90C
# 5553  清除共同帳號    nepotism   2019-06-6-4  M.1559793935.A.90C
# 5554  清除共同帳號       Nifit   2019-06-6-4  M.1559793935.A.90C
# 5555  清除共同帳號       PartX   2019-06-6-4  M.1559793935.A.90C
# 5556  清除共同帳號      passON   2019-06-6-4  M.1559793935.A.90C
# 5557  清除共同帳號      SENSEX   2019-06-6-4  M.1559793935.A.90C
# 5558  清除共同帳號        SHMn   2019-06-6-4  M.1559793935.A.90C
# 5559  清除共同帳號        SON9   2019-06-6-4  M.1559793935.A.90C
# ...      ...         ...           ...                 ...
# 7391  清除共同帳號      IDpass  2019-05-31-5  M.1559274998.A.13B
# 7392  清除共同帳號    LeOrange  2019-05-31-5  M.1559274998.A.13B
# 7393  清除共同帳號       Qatar  2019-05-31-5  M.1559274998.A.13B
# 7394  清除共同帳號       QRcat  2019-05-31-5  M.1559274998.A.13B
# 7395  清除共同帳號      ToKoYo  2019-05-31-5  M.1559274998.A.13B
# 7396  清除共同帳號    TPkiller  2019-11-24-7  M.1574574374.A.333
# 7397  清除共同帳號    headwind  2019-11-24-7  M.1574574374.A.333
# 7398  清除共同帳號       Malop  2019-11-24-7  M.1574574374.A.333
# 7399  清除共同帳號     MerryOn  2019-11-24-7  M.1574574374.A.333
# 7400  清除共同帳號      kiank2  2019-10-19-6  M.1571477742.A.DFC
# 7401  清除共同帳號      carotn  2019-10-19-6  M.1571477742.A.DFC
# 7402  清除共同帳號    raywen56  2019-10-19-6  M.1571477742.A.DFC
# 7403  清除共同帳號        ds23  2019-10-19-6  M.1571477742.A.DFC
# 7404  清除共同帳號     shiusiu  2019-10-19-6  M.1571477742.A.DFC
# 7405  清除共同帳號     AirFuck  2019-10-19-6  M.1571477742.A.DFC
# 7406  清除共同帳號    Neutronn  2019-10-19-6  M.1571477742.A.DFC
# 7407  清除共同帳號     aidener  2019-10-19-6  M.1571477742.A.DFC
# 7408  清除共同帳號   NTUlosers  2019-10-19-6  M.1571477742.A.DFC
# 7409  清除共同帳號  k131504543  2019-10-19-6  M.1571477742.A.DFC
# 7410  清除共同帳號       mckos  2019-10-19-6  M.1571477742.A.DFC
# 7411  清除共同帳號       skoen  2019-10-19-6  M.1571477742.A.DFC
# 7412  清除共同帳號        uuur  2019-10-19-6  M.1571477742.A.DFC
# 7413  清除共同帳號   chunachun  2019-10-19-6  M.1571477742.A.DFC
# 7414  清除共同帳號        naga  2019-10-19-6  M.1571477742.A.DFC
# 7415  清除共同帳號      capten  2019-10-19-6  M.1571477742.A.DFC
# 7416  清除共同帳號      achuda  2019-10-19-6  M.1571477742.A.DFC
# 7417  清除共同帳號     panpana  2019-10-19-6  M.1571477742.A.DFC
# 7418  清除共同帳號        siho  2019-10-19-6  M.1571477742.A.DFC
# 7419  清除共同帳號     doglove  2019-10-19-6  M.1571477742.A.DFC
# 7420  清除共同帳號      timefl  2019-10-19-6  M.1571477742.A.DFC
#
#                                              Popularity
# 5530  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5531  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5532  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5533  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5534  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5535  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5536  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5537  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5538  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 5539  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5540  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5541  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5542  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5543  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5544  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5545  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5546  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5547  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5548  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5549  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5550  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5551  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5552  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5553  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5554  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5555  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5556  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5557  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5558  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 5559  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# ...                                                 ...
# 7391  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 7392  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 7393  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 7394  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 7395  {'all': 1, 'count': 1, 'neutral': 0, 'boo': 0,...
# 7396  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7397  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7398  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7399  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7400  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7401  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7402  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7403  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7404  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7405  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7406  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7407  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7408  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7409  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7410  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7411  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7412  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7413  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7414  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7415  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7416  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7417  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7418  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7419  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
# 7420  {'all': 0, 'count': 0, 'neutral': 0, 'boo': 0,...
#
# [1891 rows x 5 columns]

# %%
df.to_csv('./tt.csv')
